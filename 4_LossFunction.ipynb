# %% [markdown]
# <a href="https://colab.research.google.com/github/lokeshpuma/Deep_Learning/blob/main/4_LossFunction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
y_predicted = np.array([1,1,0,0,1])
y_true = np.array([0.30,0.7,1,0,0.5])

# %% [markdown]
# ### 📐 Error Metrics
#
# **Mean Absolute Error (MAE)**
# \[
# MAE = \frac{1}{n} \sum_{i=1}^{n} \left| y_i - \hat{y}_i \right|
# \]
#
# **Mean Squared Error (MSE)**
# \[
# MSE = \frac{1}{n} \sum_{i=1}^{n} \left( y_i - \hat{y}_i \right)^2
# \]
#
# where
# - \( y_i \) = actual value
# - \( \hat{y}_i \) = predicted value
# - \( n \) = number of samples

# %%
def mae(y_true, y_predicted):
  total_error = 0
  total_error_mse = 0
  for yt,yp in zip(y_true,y_predicted):
    total_error += abs(yt-yp)
    total_error_mse += (yt-yp)**2

  print("total Error :",total_error)
  mae = total_error/len(y_true)
  print("MAE :",mae)
  mse = total_error_mse/len(y_true)
  print("MSE :",mse)
  return mae, mse

# %%
mae(y_true,y_predicted)
# Out:
# total Error : 2.5
# MAE : 0.5
# MSE : 0.366
# (np.float64(0.5), np.float64(0.366))

# %% [markdown]
# ### 📐 Log Loss / Binary Cross-Entropy
#
# **Log Loss (Binary Cross-Entropy)**
# \[
# \text{Log Loss} = -\frac{1}{n} \sum_{i=1}^{n}
# \left[
# y_i \log(\hat{y}_i) + (1 - y_i)\log(1 - \hat{y}_i)
# \right]
# \]
#
# where
# - \( y_i \) = actual label (0 or 1)
# - \( \hat{y}_i \) = predicted probability (0 < \( \hat{y}_i \) < 1)
# - \( n \) = number of samples

# %%
epsilon = 1e-15

y_predicted_new = [min(max(i, epsilon), 1 - epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
log_loss = -np.mean(y_true_np * np.log(y_predicted_new_np) + (1 - y_true_np) * np.log(1 - y_predicted_new_np))
print(log_loss)
# Out:
# 17.2696280766844

# %%
def log_loss(y_true, y_predicted):
    y_predicted_new = [max(min(i, 1 - epsilon), epsilon) for i in y_predicted]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true_np * np.log(y_predicted_new_np) + (1 - y_true_np) * np.log(1 - y_predicted_new_np))

# %%
log_loss(y_true,y_predicted)
# Out:
# np.float64(17.2696280766844)
